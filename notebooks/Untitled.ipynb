# %%
import pandas as pd

# %%
df_analysis = pd.read_csv('analysis.csv')
df_analysis.head()
# Out:
#                                                title  maxNodes  timesteps  \
# 0  /home/eduardo/Desktop/new_datasets/converted/c...       115         47
# 1  /home/eduardo/Desktop/new_datasets/converted/c...       122         48
# 2  /home/eduardo/Desktop/new_datasets/converted/c...       185         58
# 3  /home/eduardo/Desktop/new_datasets/converted/c...       123         47
# 4  /home/eduardo/Desktop/new_datasets/converted/c...        57         48
#
#    sizeSpike  sizeSmall  sizeRegular  dataSpike  dataSmall  dataRegular  \
# 0       True      False        False      False      False        False
# 1       True      False        False      False      False        False
# 2       True      False        False       True      False        False
# 3       True      False        False       True      False        False
# 4       True      False        False       True      False        False
#
#     deep  shallow  hasHighVariance  hasLowVariance
# ...

# %%
df_analysis['size'] =

# %%
df_analysis[['sizeSmall', 'sizeRegular', 'sizeSpike']]
# Out:
#       sizeSmall  sizeRegular  sizeSpike
# 0         False        False       True
# 1         False        False       True
# 2         False        False       True
# 3         False        False       True
# 4         False        False       True
# 5         False        False      False
# 6         False        False       True
# 7         False        False       True
# 8         False        False       True
# 9         False        False       True
# 10        False        False       True
# 11        False        False       True
# 12        False        False       True
# 13        False        False       True
# 14        False        False       True
# 15        False        False       True
# 16        False        False       True
# 17        False        False       True
# 18        False        False       True
# 19        False        False      False
# 20        False        False       True
# 21        False        False       True
# ...
